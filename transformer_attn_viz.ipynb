# %%
from transformers import DistilBertForSequenceClassification, DistilBertTokenizerFast, utils
from bertviz import model_view, head_view
utils.logging.set_verbosity_error()  # Suppress standard warnings

model_name = "sentiment_twitter"  # Find popular HuggingFace models here: https://huggingface.co/models
input_text = "I love my cat in my lap"  
model = DistilBertForSequenceClassification.from_pretrained(model_name, output_attentions=True)  # Configure model to return attention values
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
inputs = tokenizer.encode(input_text, return_tensors='pt')  # Tokenize input text
outputs = model(inputs)  # Run model
attention = outputs[-1]  # Retrieve attention from model outputs
tokens = tokenizer.convert_ids_to_tokens(inputs[0])  # Convert input ids to token strings
model_view(attention, tokens)  # Display model view
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-56eaee0881d44e9699c961316afb3d08'>
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
head_view(attention, tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-7cc81985e5fb46f4ba3a9674e227607c'>
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>
